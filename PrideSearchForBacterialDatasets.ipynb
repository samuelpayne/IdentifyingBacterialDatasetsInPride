# %% [markdown]
# The information for how to access PRIDE was found here http://www.ebi.ac.uk/pride/help/archive/access/webservice
# This first code block is a direct copy of theirs just to figure out how to do web-calls, and provides a nice
# test of whether their webservices are running correctly, which is not always the case.

# %%
import json
import urllib.request as urllib2


projects = ["PXD004033", "PXD003805"]
# get rid of the first argument, as it is the name of the script itself

# for each of the provided project accessions retrieve the record and print some details
for project in projects:
  try:
    # Set the request URL
    url = 'http://www.ebi.ac.uk/pride/ws/archive/project/' + project
    # Create the request
    req = urllib2.Request(url)
    # Send the request and retrieve the data
    resp = urllib2.urlopen(req).read()
    # Interpret the JSON response 
    project = json.loads(resp.decode('utf8'))
    #print (project)
    # Output some project properties 
    print(project['accession'] + ' - ' + project['title'])
    print('\tsubmission date: ' + project['publicationDate'])
    print('\tsubmission type: ' + project['submissionType'])
    print('\tsubmitter email: ' + project['submitter']['email'])
    print('\tnumber of assays: ' + str(project['numAssays']))
  except (Exception):
    print('Error for project: ' + project + ' perhaps this project does not exist?')
# Out:
# PXD004033 - Metaproteomic Monitoring of Perinatal Mouse Gut Microbiota
# 	submission date: 2016-10-13
# 	submission type: PARTIAL
# 	submitter email: stefano.levimortera@opbg.net
# 	number of assays: 0
# PXD003805 - Metaproteome of chicken gastrointestinal tract microbiota
# 	submission date: 2016-10-06
# 	submission type: PARTIAL
# 	submitter email: jseifert@uni-hohenheim.de
# 	number of assays: 0

# %%
#Given that we are going to be using this little loop for
#each batch of results from PRIDE's webservice, I figureed we should make a method out of it
import TaxonomyQueries
import PrideData

def CheckOrganismsFromBatchRequest(BatchOfResults):
    for Result in BatchOfResults:
        Object = PrideData.PrideSubmission(Result)
        ProjectAccession = Object.GetAccession()
        OrganismList = Object.GetOrgList()
       
        for Org in OrganismList:
            # 1. check to see if I have seen this before
            if Org in Dictionary_IsNotBacteria:
                #don't really care about it
                continue
            if Org in Dictionary_IsBacteria:
                #there is an organism in this project that is a bacteria! Hooray!
                #save this to the list of objects that I care about
                PrideSubmissionsWithBacteria.append(Object)
                continue
            #I only get here because Org has not been seen before. Time for the NCBI web calls
            #sometimes, they add parenthetical stuff about strains or common names. So let's 
            #just get the first two and that will be genus, species
            TaxonID = 0
            ManyNames = Org.split(' ')
            if len(ManyNames) < 2:
                TaxonID = TaxonomyQueries.GetTaxonIDFromSingleWord(ManyNames[0])
            else:
                TaxonID = TaxonomyQueries.GetTaxonIDFromGenusSpecies(ManyNames[0], ManyNames[1])
            if TaxonID == 0:
                #we had one of several failures here. Print some error message and move on
                #notably we don't do anything with the created Object. Just let it die 
                print("Error: Unable to get TaxonID for :%s: project %s"%(Org, ProjectAccession))
                continue
                
            IsBacteria = TaxonomyQueries.TestIsBacteriaWithTaxonID(TaxonID)
            if IsBacteria:
                Dictionary_IsBacteria[Org] = TaxonID
                PrideSubmissionsWithBacteria.append(Object)
            else:
                Dictionary_IsNotBacteria[Org] = TaxonID

# %%
#set aside some arrays to keep track of things that i've seen before. I don't want to keep calling
#the webservice if I don't have to
Dictionary_IsBacteria = {} # key = species, value = taxonID
Dictionary_IsNotBacteria = {} # key = species, value = taxonID
PrideSubmissionsWithBacteria = [] #array of objects

# %%
#1. Get an idea of how many projects there are at PRIDE
url_numProjects = 'http://www.ebi.ac.uk/pride/ws/archive/project/count'
req = urllib2.Request(url_numProjects)
# Send the request and retrieve the data
resp = urllib2.urlopen(req).read()
#this response is a byte (datatype) #print (type(resp))

NumProjects = int(resp)
#NumProjects = 91 # a cutout for testing
BatchSize = 10
Pages = (NumProjects//BatchSize) + 1 #double division means integer division (floor the float)

#2. Now we iteratively query the EBI webservices to learn about projects.
#   We are specifically interested in finding submissions that contain Bacterial species
for PageNumber in range(Pages):
    #build a URL to get back batches of projects projects
    url = 'http://www.ebi.ac.uk/pride/ws/archive/project/list?show=%s&page=%s&order=desc'%(BatchSize,PageNumber)
    print ("**Sending webRequest to EBI for PRIDE projects, page %s of %s"%(PageNumber, Pages))
    #print (url)
    req = urllib2.Request(url)
    # Send the request and retrieve the data
    resp = urllib2.urlopen(req).read()
    # Interpret the JSON response 
    ProjectBatch = json.loads(resp.decode('utf8'))
    # type(ProjectBatch) ##found out this is a dictionary with one key value pair. 
    # key = 'list' , value is a big list of stuff I think.
    ListOfResults = ProjectBatch['list']
    CheckOrganismsFromBatchRequest(ListOfResults)
# Out:
# **Sending webRequest to EBI for PRIDE projects, page 0 of 304
# **Sending webRequest to EBI for PRIDE projects, page 1 of 304
# **Sending webRequest to EBI for PRIDE projects, page 2 of 304
# **Sending webRequest to EBI for PRIDE projects, page 3 of 304
# Error: Unable to get TaxonID for :human gut metagenome: project PXD004039
# **Sending webRequest to EBI for PRIDE projects, page 4 of 304
# **Sending webRequest to EBI for PRIDE projects, page 5 of 304
# **Sending webRequest to EBI for PRIDE projects, page 6 of 304
# Error: Unable to get TaxonID for :thiotrophic endosymbiont of Bathymodiolus azoricus (Menez Gwen): project PXD004061
# Error: Unable to get TaxonID for :methanotrophic endosymbiont of Bathymodiolus azoricus (Menez Gwen): project PXD004061
# **Sending webRequest to EBI for PRIDE projects, page 7 of 304
# **Sending webRequest to EBI for PRIDE projects, page 8 of 304
# **Sending webRequest to EBI for PRIDE projects, page 9 of 304
# **Sending webRequest to EBI for PRIDE projects, page 10 of 304
# **Sending webRequest to EBI for PRIDE projects, page 11 of 304
# **Sending webRequest to EBI for PRIDE projects, page 12 of 304
# **Sending webRequest to EBI for PRIDE projects, page 13 of 304
# **Sending webRequest to EBI for PRIDE projects, page 14 of 304
# **Sending webRequest to EBI for PRIDE projects, page 15 of 304
# **Sending webRequest to EBI for PRIDE projects, page 16 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD004096
# **Sending webRequest to EBI for PRIDE projects, page 17 of 304
# **Sending webRequest to EBI for PRIDE projects, page 18 of 304
# **Sending webRequest to EBI for PRIDE projects, page 19 of 304
# **Sending webRequest to EBI for PRIDE projects, page 20 of 304
# **Sending webRequest to EBI for PRIDE projects, page 21 of 304
# **Sending webRequest to EBI for PRIDE projects, page 22 of 304
# **Sending webRequest to EBI for PRIDE projects, page 23 of 304
# **Sending webRequest to EBI for PRIDE projects, page 24 of 304
# **Sending webRequest to EBI for PRIDE projects, page 25 of 304
# **Sending webRequest to EBI for PRIDE projects, page 26 of 304
# **Sending webRequest to EBI for PRIDE projects, page 27 of 304
# **Sending webRequest to EBI for PRIDE projects, page 28 of 304
# **Sending webRequest to EBI for PRIDE projects, page 29 of 304
# Error: Unable to get TaxonID for :Eucalyptus spp. mixed library: project PXD003504
# **Sending webRequest to EBI for PRIDE projects, page 30 of 304
# **Sending webRequest to EBI for PRIDE projects, page 31 of 304
# **Sending webRequest to EBI for PRIDE projects, page 32 of 304
# **Sending webRequest to EBI for PRIDE projects, page 33 of 304
# **Sending webRequest to EBI for PRIDE projects, page 34 of 304
# **Sending webRequest to EBI for PRIDE projects, page 35 of 304
# **Sending webRequest to EBI for PRIDE projects, page 36 of 304
# Error: Unable to get TaxonID for :Recombinant Hepatitis C virus J6/JFH1-J6: project PXD000988
# **Sending webRequest to EBI for PRIDE projects, page 37 of 304
# **Sending webRequest to EBI for PRIDE projects, page 38 of 304
# **Sending webRequest to EBI for PRIDE projects, page 39 of 304
# **Sending webRequest to EBI for PRIDE projects, page 40 of 304
# **Sending webRequest to EBI for PRIDE projects, page 41 of 304
# Error: Unable to get TaxonID for :human gut metagenome: project PXD003528
# Error: Unable to get TaxonID for :mouse gut metagenome: project PXD003527
# **Sending webRequest to EBI for PRIDE projects, page 42 of 304
# **Sending webRequest to EBI for PRIDE projects, page 43 of 304
# **Sending webRequest to EBI for PRIDE projects, page 44 of 304
# Error: Unable to get TaxonID for :Pseudovibrio sp. (strain FO-BEG1)�: project PXD001621
# Error: Unable to get TaxonID for :Pseudovibrio sp. (strain FO-BEG1)�: project PXD001624
# **Sending webRequest to EBI for PRIDE projects, page 45 of 304
# Error: Unable to get TaxonID for :53655: project PXD001664
# **Sending webRequest to EBI for PRIDE projects, page 46 of 304
# Error: Unable to get TaxonID for :Unidentified Influenza A virus (H1N1): project PXD003803
# **Sending webRequest to EBI for PRIDE projects, page 47 of 304
# **Sending webRequest to EBI for PRIDE projects, page 48 of 304
# **Sending webRequest to EBI for PRIDE projects, page 49 of 304
# **Sending webRequest to EBI for PRIDE projects, page 50 of 304
# **Sending webRequest to EBI for PRIDE projects, page 51 of 304
# **Sending webRequest to EBI for PRIDE projects, page 52 of 304
# **Sending webRequest to EBI for PRIDE projects, page 53 of 304
# **Sending webRequest to EBI for PRIDE projects, page 54 of 304
# **Sending webRequest to EBI for PRIDE projects, page 55 of 304
# **Sending webRequest to EBI for PRIDE projects, page 56 of 304
# **Sending webRequest to EBI for PRIDE projects, page 57 of 304
# **Sending webRequest to EBI for PRIDE projects, page 58 of 304
# **Sending webRequest to EBI for PRIDE projects, page 59 of 304
# **Sending webRequest to EBI for PRIDE projects, page 60 of 304
# **Sending webRequest to EBI for PRIDE projects, page 61 of 304
# **Sending webRequest to EBI for PRIDE projects, page 62 of 304
# **Sending webRequest to EBI for PRIDE projects, page 63 of 304
# **Sending webRequest to EBI for PRIDE projects, page 64 of 304
# **Sending webRequest to EBI for PRIDE projects, page 65 of 304
# **Sending webRequest to EBI for PRIDE projects, page 66 of 304
# **Sending webRequest to EBI for PRIDE projects, page 67 of 304
# **Sending webRequest to EBI for PRIDE projects, page 68 of 304
# **Sending webRequest to EBI for PRIDE projects, page 69 of 304
# **Sending webRequest to EBI for PRIDE projects, page 70 of 304
# **Sending webRequest to EBI for PRIDE projects, page 71 of 304
# **Sending webRequest to EBI for PRIDE projects, page 72 of 304
# **Sending webRequest to EBI for PRIDE projects, page 73 of 304
# **Sending webRequest to EBI for PRIDE projects, page 74 of 304
# **Sending webRequest to EBI for PRIDE projects, page 75 of 304
# **Sending webRequest to EBI for PRIDE projects, page 76 of 304
# **Sending webRequest to EBI for PRIDE projects, page 77 of 304
# **Sending webRequest to EBI for PRIDE projects, page 78 of 304
# **Sending webRequest to EBI for PRIDE projects, page 79 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001774
# **Sending webRequest to EBI for PRIDE projects, page 80 of 304
# **Sending webRequest to EBI for PRIDE projects, page 81 of 304
# **Sending webRequest to EBI for PRIDE projects, page 82 of 304
# **Sending webRequest to EBI for PRIDE projects, page 83 of 304
# **Sending webRequest to EBI for PRIDE projects, page 84 of 304
# **Sending webRequest to EBI for PRIDE projects, page 85 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD002291
# **Sending webRequest to EBI for PRIDE projects, page 86 of 304
# **Sending webRequest to EBI for PRIDE projects, page 87 of 304
# Error: Unable to get TaxonID for :Avian infectious bronchitis virus (strain Beaudette CK) (IBV): project PXD002936
# **Sending webRequest to EBI for PRIDE projects, page 88 of 304
# **Sending webRequest to EBI for PRIDE projects, page 89 of 304
# **Sending webRequest to EBI for PRIDE projects, page 90 of 304
# **Sending webRequest to EBI for PRIDE projects, page 91 of 304
# **Sending webRequest to EBI for PRIDE projects, page 92 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001429
# **Sending webRequest to EBI for PRIDE projects, page 93 of 304
# **Sending webRequest to EBI for PRIDE projects, page 94 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD002740
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD002739
# **Sending webRequest to EBI for PRIDE projects, page 95 of 304
# **Sending webRequest to EBI for PRIDE projects, page 96 of 304
# **Sending webRequest to EBI for PRIDE projects, page 97 of 304
# **Sending webRequest to EBI for PRIDE projects, page 98 of 304
# **Sending webRequest to EBI for PRIDE projects, page 99 of 304
# **Sending webRequest to EBI for PRIDE projects, page 100 of 304
# Error: Unable to get TaxonID for :Influenza B virus (B/Memphis/13/03): project PXD002234
# Error: Unable to get TaxonID for :Influenza A virus (A/Vietnam/1203/04(H5N1)): project PXD002234
# **Sending webRequest to EBI for PRIDE projects, page 101 of 304
# **Sending webRequest to EBI for PRIDE projects, page 102 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD003156
# **Sending webRequest to EBI for PRIDE projects, page 103 of 304
# **Sending webRequest to EBI for PRIDE projects, page 104 of 304
# **Sending webRequest to EBI for PRIDE projects, page 105 of 304
# **Sending webRequest to EBI for PRIDE projects, page 106 of 304
# **Sending webRequest to EBI for PRIDE projects, page 107 of 304
# **Sending webRequest to EBI for PRIDE projects, page 108 of 304
# Error: Unable to get TaxonID for :berry: project PXD001661
# **Sending webRequest to EBI for PRIDE projects, page 109 of 304
# **Sending webRequest to EBI for PRIDE projects, page 110 of 304
# **Sending webRequest to EBI for PRIDE projects, page 111 of 304
# Error: Unable to get TaxonID for :microbial mat metagenome: project PXD003119
# Error: Unable to get TaxonID for :microbial mat metagenome: project PXD003125
# **Sending webRequest to EBI for PRIDE projects, page 112 of 304
# **Sending webRequest to EBI for PRIDE projects, page 113 of 304
# **Sending webRequest to EBI for PRIDE projects, page 114 of 304
# **Sending webRequest to EBI for PRIDE projects, page 115 of 304
# **Sending webRequest to EBI for PRIDE projects, page 116 of 304
# **Sending webRequest to EBI for PRIDE projects, page 117 of 304
# Error: Unable to get TaxonID for :Strawberry leafy fruit phytoplasma: project PXD002758
# **Sending webRequest to EBI for PRIDE projects, page 118 of 304
# **Sending webRequest to EBI for PRIDE projects, page 119 of 304
# **Sending webRequest to EBI for PRIDE projects, page 120 of 304
# **Sending webRequest to EBI for PRIDE projects, page 121 of 304
# **Sending webRequest to EBI for PRIDE projects, page 122 of 304
# **Sending webRequest to EBI for PRIDE projects, page 123 of 304
# **Sending webRequest to EBI for PRIDE projects, page 124 of 304
# **Sending webRequest to EBI for PRIDE projects, page 125 of 304
# **Sending webRequest to EBI for PRIDE projects, page 126 of 304
# **Sending webRequest to EBI for PRIDE projects, page 127 of 304
# **Sending webRequest to EBI for PRIDE projects, page 128 of 304
# **Sending webRequest to EBI for PRIDE projects, page 129 of 304
# **Sending webRequest to EBI for PRIDE projects, page 130 of 304
# **Sending webRequest to EBI for PRIDE projects, page 131 of 304
# **Sending webRequest to EBI for PRIDE projects, page 132 of 304
# **Sending webRequest to EBI for PRIDE projects, page 133 of 304
# **Sending webRequest to EBI for PRIDE projects, page 134 of 304
# **Sending webRequest to EBI for PRIDE projects, page 135 of 304
# Error: Unable to get TaxonID for :anaerobic digester metagenome: project PXD002420
# **Sending webRequest to EBI for PRIDE projects, page 136 of 304
# **Sending webRequest to EBI for PRIDE projects, page 137 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001046
# **Sending webRequest to EBI for PRIDE projects, page 138 of 304
# **Sending webRequest to EBI for PRIDE projects, page 139 of 304
# Error: Unable to get TaxonID for :uncultured marine microorganism: project PXD002641
# **Sending webRequest to EBI for PRIDE projects, page 140 of 304
# **Sending webRequest to EBI for PRIDE projects, page 141 of 304
# **Sending webRequest to EBI for PRIDE projects, page 142 of 304
# **Sending webRequest to EBI for PRIDE projects, page 143 of 304
# **Sending webRequest to EBI for PRIDE projects, page 144 of 304
# **Sending webRequest to EBI for PRIDE projects, page 145 of 304
# **Sending webRequest to EBI for PRIDE projects, page 146 of 304
# **Sending webRequest to EBI for PRIDE projects, page 147 of 304
# **Sending webRequest to EBI for PRIDE projects, page 148 of 304
# **Sending webRequest to EBI for PRIDE projects, page 149 of 304
# Error: Unable to get TaxonID for :Daphnia (common water fleas): project PXD001787
# **Sending webRequest to EBI for PRIDE projects, page 150 of 304
# **Sending webRequest to EBI for PRIDE projects, page 151 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD002222
# **Sending webRequest to EBI for PRIDE projects, page 152 of 304
# **Sending webRequest to EBI for PRIDE projects, page 153 of 304
# **Sending webRequest to EBI for PRIDE projects, page 154 of 304
# **Sending webRequest to EBI for PRIDE projects, page 155 of 304
# **Sending webRequest to EBI for PRIDE projects, page 156 of 304
# **Sending webRequest to EBI for PRIDE projects, page 157 of 304
# **Sending webRequest to EBI for PRIDE projects, page 158 of 304
# **Sending webRequest to EBI for PRIDE projects, page 159 of 304
# **Sending webRequest to EBI for PRIDE projects, page 160 of 304
# **Sending webRequest to EBI for PRIDE projects, page 161 of 304
# **Sending webRequest to EBI for PRIDE projects, page 162 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000951
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000857
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001168
# **Sending webRequest to EBI for PRIDE projects, page 163 of 304
# **Sending webRequest to EBI for PRIDE projects, page 164 of 304
# **Sending webRequest to EBI for PRIDE projects, page 165 of 304
# Error: Unable to get TaxonID for :Streptoccous pyogenes: project PXD002037
# **Sending webRequest to EBI for PRIDE projects, page 166 of 304
# **Sending webRequest to EBI for PRIDE projects, page 167 of 304
# **Sending webRequest to EBI for PRIDE projects, page 168 of 304
# **Sending webRequest to EBI for PRIDE projects, page 169 of 304
# **Sending webRequest to EBI for PRIDE projects, page 170 of 304
# **Sending webRequest to EBI for PRIDE projects, page 171 of 304
# Error: Unable to get TaxonID for :Cercopithecidae (Old World monkeys): project PXD001330
# **Sending webRequest to EBI for PRIDE projects, page 172 of 304
# **Sending webRequest to EBI for PRIDE projects, page 173 of 304
# **Sending webRequest to EBI for PRIDE projects, page 174 of 304
# **Sending webRequest to EBI for PRIDE projects, page 175 of 304
# **Sending webRequest to EBI for PRIDE projects, page 176 of 304
# **Sending webRequest to EBI for PRIDE projects, page 177 of 304
# **Sending webRequest to EBI for PRIDE projects, page 178 of 304
# **Sending webRequest to EBI for PRIDE projects, page 179 of 304
# **Sending webRequest to EBI for PRIDE projects, page 180 of 304
# **Sending webRequest to EBI for PRIDE projects, page 181 of 304
# **Sending webRequest to EBI for PRIDE projects, page 182 of 304
# **Sending webRequest to EBI for PRIDE projects, page 183 of 304
# **Sending webRequest to EBI for PRIDE projects, page 184 of 304
# **Sending webRequest to EBI for PRIDE projects, page 185 of 304
# **Sending webRequest to EBI for PRIDE projects, page 186 of 304
# Error: Unable to get TaxonID for :Streptoccous pyogenes: project PXD001091
# **Sending webRequest to EBI for PRIDE projects, page 187 of 304
# **Sending webRequest to EBI for PRIDE projects, page 188 of 304
# **Sending webRequest to EBI for PRIDE projects, page 189 of 304
# **Sending webRequest to EBI for PRIDE projects, page 190 of 304
# **Sending webRequest to EBI for PRIDE projects, page 191 of 304
# **Sending webRequest to EBI for PRIDE projects, page 192 of 304
# **Sending webRequest to EBI for PRIDE projects, page 193 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000763
# **Sending webRequest to EBI for PRIDE projects, page 194 of 304
# **Sending webRequest to EBI for PRIDE projects, page 195 of 304
# **Sending webRequest to EBI for PRIDE projects, page 196 of 304
# **Sending webRequest to EBI for PRIDE projects, page 197 of 304
# **Sending webRequest to EBI for PRIDE projects, page 198 of 304
# **Sending webRequest to EBI for PRIDE projects, page 199 of 304
# **Sending webRequest to EBI for PRIDE projects, page 200 of 304
# **Sending webRequest to EBI for PRIDE projects, page 201 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001058
# **Sending webRequest to EBI for PRIDE projects, page 202 of 304
# **Sending webRequest to EBI for PRIDE projects, page 203 of 304
# **Sending webRequest to EBI for PRIDE projects, page 204 of 304
# **Sending webRequest to EBI for PRIDE projects, page 205 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000923
# **Sending webRequest to EBI for PRIDE projects, page 206 of 304
# **Sending webRequest to EBI for PRIDE projects, page 207 of 304
# **Sending webRequest to EBI for PRIDE projects, page 208 of 304
# **Sending webRequest to EBI for PRIDE projects, page 209 of 304
# **Sending webRequest to EBI for PRIDE projects, page 210 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD001030
# **Sending webRequest to EBI for PRIDE projects, page 211 of 304
# **Sending webRequest to EBI for PRIDE projects, page 212 of 304
# **Sending webRequest to EBI for PRIDE projects, page 213 of 304
# **Sending webRequest to EBI for PRIDE projects, page 214 of 304
# **Sending webRequest to EBI for PRIDE projects, page 215 of 304
# **Sending webRequest to EBI for PRIDE projects, page 216 of 304
# **Sending webRequest to EBI for PRIDE projects, page 217 of 304
# **Sending webRequest to EBI for PRIDE projects, page 218 of 304
# **Sending webRequest to EBI for PRIDE projects, page 219 of 304
# **Sending webRequest to EBI for PRIDE projects, page 220 of 304
# **Sending webRequest to EBI for PRIDE projects, page 221 of 304
# **Sending webRequest to EBI for PRIDE projects, page 222 of 304
# **Sending webRequest to EBI for PRIDE projects, page 223 of 304
# **Sending webRequest to EBI for PRIDE projects, page 224 of 304
# **Sending webRequest to EBI for PRIDE projects, page 225 of 304
# **Sending webRequest to EBI for PRIDE projects, page 226 of 304
# Error: Unable to get TaxonID for :unidentified soil organism: project PXD000410
# **Sending webRequest to EBI for PRIDE projects, page 227 of 304
# **Sending webRequest to EBI for PRIDE projects, page 228 of 304
# **Sending webRequest to EBI for PRIDE projects, page 229 of 304
# **Sending webRequest to EBI for PRIDE projects, page 230 of 304
# **Sending webRequest to EBI for PRIDE projects, page 231 of 304
# **Sending webRequest to EBI for PRIDE projects, page 232 of 304
# **Sending webRequest to EBI for PRIDE projects, page 233 of 304
# **Sending webRequest to EBI for PRIDE projects, page 234 of 304
# **Sending webRequest to EBI for PRIDE projects, page 235 of 304
# **Sending webRequest to EBI for PRIDE projects, page 236 of 304
# **Sending webRequest to EBI for PRIDE projects, page 237 of 304
# **Sending webRequest to EBI for PRIDE projects, page 238 of 304
# Error: Unable to get TaxonID for :Firmicutes (gram-positive bacteria): project PXD000187
# **Sending webRequest to EBI for PRIDE projects, page 239 of 304
# **Sending webRequest to EBI for PRIDE projects, page 240 of 304
# **Sending webRequest to EBI for PRIDE projects, page 241 of 304
# **Sending webRequest to EBI for PRIDE projects, page 242 of 304
# **Sending webRequest to EBI for PRIDE projects, page 243 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000313
# Error: Unable to get TaxonID for :Rice(O. sativa): project PXD000265
# Error: Unable to get TaxonID for :Human immunodeficiency virus 1: project PXD000064
# **Sending webRequest to EBI for PRIDE projects, page 244 of 304
# **Sending webRequest to EBI for PRIDE projects, page 245 of 304
# **Sending webRequest to EBI for PRIDE projects, page 246 of 304
# **Sending webRequest to EBI for PRIDE projects, page 247 of 304
# **Sending webRequest to EBI for PRIDE projects, page 248 of 304
# **Sending webRequest to EBI for PRIDE projects, page 249 of 304
# **Sending webRequest to EBI for PRIDE projects, page 250 of 304
# **Sending webRequest to EBI for PRIDE projects, page 251 of 304
# **Sending webRequest to EBI for PRIDE projects, page 252 of 304
# Error: Unable to get TaxonID for :Drosophila (fruit flies): project PXD000043
# **Sending webRequest to EBI for PRIDE projects, page 253 of 304
# **Sending webRequest to EBI for PRIDE projects, page 254 of 304
# **Sending webRequest to EBI for PRIDE projects, page 255 of 304
# **Sending webRequest to EBI for PRIDE projects, page 256 of 304
# **Sending webRequest to EBI for PRIDE projects, page 257 of 304
# **Sending webRequest to EBI for PRIDE projects, page 258 of 304
# **Sending webRequest to EBI for PRIDE projects, page 259 of 304
# Error: Unable to get TaxonID for :Murine leukemia virus: project PRD000480
# Error: Unable to get TaxonID for :Murine leukemia virus: project PRD000479
# **Sending webRequest to EBI for PRIDE projects, page 260 of 304
# **Sending webRequest to EBI for PRIDE projects, page 261 of 304
# **Sending webRequest to EBI for PRIDE projects, page 262 of 304
# **Sending webRequest to EBI for PRIDE projects, page 263 of 304
# **Sending webRequest to EBI for PRIDE projects, page 264 of 304
# **Sending webRequest to EBI for PRIDE projects, page 265 of 304
# **Sending webRequest to EBI for PRIDE projects, page 266 of 304
# Error: Unable to get TaxonID for :Synechococcus phage S-SSM7: project PRD000685
# Error: Unable to get TaxonID for :Siphoviridae (phages with long non-contractile tails): project PRD000685
# Error: Unable to get TaxonID for :Synechococcus phage syn9: project PRD000685
# Error: Unable to get TaxonID for :Enterobacteria phage Mu (Bacteriophage Mu): project PRD000685
# Error: Unable to get TaxonID for :Listeria phage A118 (Bacteriophage A118): project PRD000685
# Error: Unable to get TaxonID for :Enterobacteria phage T4 (Bacteriophage T4): project PRD000679
# Error: Unable to get TaxonID for :Enterobacteria phage Mu (Bacteriophage Mu): project PRD000679
# Error: Unable to get TaxonID for :Mytilus edulis/galloprovincialis MCLGV-2007: project PRD000541
# **Sending webRequest to EBI for PRIDE projects, page 267 of 304
# **Sending webRequest to EBI for PRIDE projects, page 268 of 304
# **Sending webRequest to EBI for PRIDE projects, page 269 of 304
# **Sending webRequest to EBI for PRIDE projects, page 270 of 304
# **Sending webRequest to EBI for PRIDE projects, page 271 of 304
# **Sending webRequest to EBI for PRIDE projects, page 272 of 304
# Error: Unable to get TaxonID for :unidentified chimeric sequence: project PRD000211
# **Sending webRequest to EBI for PRIDE projects, page 273 of 304
# **Sending webRequest to EBI for PRIDE projects, page 274 of 304
# **Sending webRequest to EBI for PRIDE projects, page 275 of 304
# **Sending webRequest to EBI for PRIDE projects, page 276 of 304
# **Sending webRequest to EBI for PRIDE projects, page 277 of 304
# **Sending webRequest to EBI for PRIDE projects, page 278 of 304
# Error: Unable to get TaxonID for :O. sativa Indica Group: project PRD000357
# **Sending webRequest to EBI for PRIDE projects, page 279 of 304
# **Sending webRequest to EBI for PRIDE projects, page 280 of 304
# **Sending webRequest to EBI for PRIDE projects, page 281 of 304
# **Sending webRequest to EBI for PRIDE projects, page 282 of 304
# **Sending webRequest to EBI for PRIDE projects, page 283 of 304
# Error: Unable to get TaxonID for :Rice(O. sativa): project PRD000361
# **Sending webRequest to EBI for PRIDE projects, page 284 of 304
# **Sending webRequest to EBI for PRIDE projects, page 285 of 304
# **Sending webRequest to EBI for PRIDE projects, page 286 of 304
# Error: Unable to get TaxonID for :O. sativa Indica Group: project PRD000183
# **Sending webRequest to EBI for PRIDE projects, page 287 of 304
# **Sending webRequest to EBI for PRIDE projects, page 288 of 304
# **Sending webRequest to EBI for PRIDE projects, page 289 of 304
# Error: Unable to get TaxonID for :Dictyosteliida (dictyostelid cellular slime molds): project PRD000204
# **Sending webRequest to EBI for PRIDE projects, page 290 of 304
# **Sending webRequest to EBI for PRIDE projects, page 291 of 304
# **Sending webRequest to EBI for PRIDE projects, page 292 of 304
# **Sending webRequest to EBI for PRIDE projects, page 293 of 304
# **Sending webRequest to EBI for PRIDE projects, page 294 of 304
# **Sending webRequest to EBI for PRIDE projects, page 295 of 304
# **Sending webRequest to EBI for PRIDE projects, page 296 of 304
# **Sending webRequest to EBI for PRIDE projects, page 297 of 304
# Error: Unable to get TaxonID for :Pseudomonas phage phiKZ: project PRD000080
# Error: Unable to get TaxonID for :Pseudomonas phage EL: project PRD000080
# **Sending webRequest to EBI for PRIDE projects, page 298 of 304
# **Sending webRequest to EBI for PRIDE projects, page 299 of 304
# **Sending webRequest to EBI for PRIDE projects, page 300 of 304
# **Sending webRequest to EBI for PRIDE projects, page 301 of 304
# **Sending webRequest to EBI for PRIDE projects, page 302 of 304
# **Sending webRequest to EBI for PRIDE projects, page 303 of 304

# %%
#now I should try and figure out how much coverage exists for these data sets. Perhaps some of them are really small.

#for the moment, just try and aggregate things
for Project in PrideSubmissionsWithBacteria:
    InstrumentList = Project.GetInstrument()
    OrgList = Project.GetOrgList()
    #print (InstrumentList)
    if not 'Q Exactive' in InstrumentList:
        continue
    print ("%s: %s: %s" %(OrgList, Project.GetAccession(), Project.GetDescription()))
# Out:
# ['Streptococcus pyogenes M1 GAS']: PXD005167: Proteomics characterisation of membrane vesicles (MV) and corres
# ['Mycobacterium marinum ATCC BAA-535']: PXD003766: Pathogenic mycobacteria contain up to five type VII secretion (T
# ['Clostridia']: PXD004512: Metaproteomics was used to identify proteins from a mized commun
# ['Homo sapiens (Human)', 'Escherichia coli']: PXD003640: Despite the outstanding advantages that isobaric labelling has t
# ['Escherichia coli']: PXD003468: To study incorporation of nonproteinogenic amino acids in bacter
# ['Streptococcus pyogenes serotype M1 (strain ATCC BAA-947 / MGAS5005)', 'Homo sapiens (Human)', 'Mus musculus (Mouse)']: PXD003405: In order to test the usability of the new MS feature detection a
# ['Alteromonas macleodii ATCC 27126', 'Breviatea', 'Arcobacter']: PXD003275: The Breviatea form a lineage of free-living protists that emerge
# ['Alteromonas macleodii ATCC 27126', 'Breviatea', 'Arcobacter']: PXD003275: The Breviatea form a lineage of free-living protists that emerge
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Mycobacterium avium 100', 'Mycobacterium tuberculosis str. Beijing/W BT1', 'Mycobacterium bovis BCG', 'Mycobacterium bovis str. Ravenel', 'Mycobacterium tuberculosis LAM7', 'Mycobacterium tuberculosis CAS', 'Mycobacterium tuberculosis H37Rv']: PXD004165: Mycobacterium tuberculosis is the causitive agent of TB, which i
# ['Cellvibrio japonicus (strain Ueda107) (Pseudomonas fluorescens subsp. cellulosa)']: PXD002843: Study of the secretome of Cellvibrio japonicus after growth on d
# ['Synechococcus sp. (strain WH8102)']: PXD003976: Synechococcus strain WH8102 grown with a range of iron concentra
# ['Pseudomonas syringae', 'Arabidopsis thaliana (Mouse-ear cress)']: PXD001344: Modification of plant immune complexes by pathogen effectors can
# ['Escherichia coli']: PXD003833: Proteome-derived peptide libraries are a powerful tool for the i
# ['Escherichia coli']: PXD002785: Proteome-derived peptide libraries are a powerful tool for the i
# ['Corynebacterineae']: PXD001989: Tuberculosis, caused by the pathogen Mycobacterium tuberculosis
# ['Synechocystis sp. (strain PCC 6803 / Kazusa)']: PXD003149: The MS analysis is part of a wider study into chlorophyll biosyn
# ['Mycobacterium smegmatis (strain ATCC 700084 / mc(2)155)']: PXD003500: Biochemical evidence is vital for accurate genome annotation. Th
# ['Acaryochloris marina (strain MBIC 11017)']: PXD003139: The aim of this project is to identify, by bottom-up proteomic a
# ['Pasteurella multocida subsp. multocida str. Pm70']: PXD003586: Quantitative proteomics comparison wt and Hfq mutant Pasteurella
# ['Salmonella typhimurium (strain LT2 / SGSC1412 / ATCC 700720)']: PXD003495: Synonymous mutations do not change the sequence of the polypepti
# ['Dehalococcoides mccartyi (strain CBDB1)']: PXD003081: The proteome of the anaerobic bacterium Dehalococcoides mccartyi
# ['Escherichia coli']: PXD003342: The identification of protein C-termini in complex proteomes is
# ['Salmonella enterica subsp. enterica serovar Typhimurium str. SL1344']: PXD003113: Bacterial type III secretion systems are cell envelope-spanning
# ['Pseudomonas aeruginosa PAO1H2O']: PXD002369: Drug resistance and tolerance eliminate the therapeutic potentia
# ['Francisella tularensis subsp. holarctica FSC200']: PXD002123: The present study deals with the cross-talk of polysaccharide bi
# ['Corynebacterium glutamicum (strain ATCC 13032 / K051)']: PXD001662: Profiles of two major acyl-modifications, lysine acetylation and
# ['Bacillus thuringiensis Bt407']: PXD003311: In Gram-positive bacteria, cell-cell communication mainly relies
# ['Enterococcus faecalis (Streptococcus faecalis)']: PXD001345: Identification of proteins in the secretome of Enterococcus Faec
# ['Bacillus subtilis subsp. subtilis str. 168']: PXD001298: Highly efficient phosphopeptide enrichment developed for bacteri
# ['Klebsiella pneumoniae subsp. pneumoniae NTUH-K2044']: PXD001263: Highly efficient phosphopeptide enrichment developed for bacteri
# ['Pseudomonas aeruginosa PAO1']: PXD002605: . The transition of the opportunistic pathogen Pseudomonas aerug
# ['Staphylococcus aureus']: PXD000702: Staphylococcus aureus HG001, detection of staphyococcal proteins
# ['Pseudomonas putida (strain F1 / ATCC 700007)']: PXD001219: The genus Pseudomonas is a very versatile and heterogeneous grou
# ['Bacillus subtilis subsp. subtilis str. 168']: PXD001615: The two major acyl-modifications on lysine residues, acetylation
# ['Homo sapiens (Human)', 'Escherichia coli', 'Mus musculus (Mouse)', "Saccharomyces cerevisiae (Baker's yeast)"]: PXD002277: Recent studies have shown that lysines can be posttranslationall
# ['Homo sapiens (Human)', 'Escherichia coli']: PXD001385: We present a unique data set for benchmarking label free quantit
# ['Lactococcus lactis']: PXD001602: L. lactis was grown in steady-state cultures at specific growth
# ['Francisella tularensis subsp. novicida (strain U112)']: PXD001584: Metabolic adaptation has recently been recognized as a key compo
# ['Homo sapiens (Human)', 'Escherichia coli']: PXD001587: This dataset consists of 44 raw MS files, comprising 27 DIA (SWA
# ['Escherichia coli']: PXD000814: Proteomics study on the periplasmic chaperone network in Escheri
# ['Homo sapiens (Human)', 'Escherichia coli']: PXD001111: Here, we describe a novel LC system enabling rapid protein/prote
# ['Pseudomonas aeruginosa PAO1']: PXD001373: The newly identified functional amyloids in <i>Pseudomonas</i> (
# ['Escherichia coli']: PXD001226: Although protein acetylation is widely observed, it has been ass
# ['Homo sapiens (Human)', 'Escherichia coli']: PXD000279: We developed a set of algorithms for label-free quantification,
# ['Staphylococcus aureus']: PXD001003: We comparatively analyzed survival and physiological adaptation
# ['Desulfotomaculum reducens (strain MI-1)']: PXD001072: Desulfotomaculum reducens strain MI-1 is a Gram-positive, sulfat
# ['Bacillus subtilis subsp. subtilis str. 168']: PXD000273: Application of a novel TiO2-based phosphopeptide enrichment prot
# ['Shewanella oneidensis (strain MR-1)']: PXD000322: Logistic regression classification models were fit to manually c
